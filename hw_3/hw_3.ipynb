# %%
import os
import networkx as nx

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
project_path = os.getcwd() + '/'

browser_data_path = 'data/'
pycharm_data_path = project_path + 'hw_3/data/'

# selected_data_path = browser_data_path
selected_data_path = pycharm_data_path

# %%
testGraph = nx.fast_gnp_random_graph(500, 0.2, directed=True)

node_positions = nx.spring_layout(testGraph, k=1, iterations=10)
nx.draw(testGraph, node_positions, with_labels=False)
